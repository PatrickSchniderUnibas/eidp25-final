# %% [markdown]
# # Einführung in die Programmierung
# ## Prüfung vom 13. Januar 2026
# ### Zeit: 80 Minuten

# %% [markdown]
# *Schreiben Sie in dieses Feld Ihren Vornamen, Namen und email Adresse.*

# %% [markdown]
# ## Übersetzungstool
#
# Sie dürfen das Übersetzungstool [Google Translate](https://translate.google.com) verwenden.

# %% [markdown]
# ## Theorie (10 Punkte)

# %% [markdown]
# ### Aufgabe 1 (2 Punkte)
#
# Welche der folgenden Aussagen sind wahr?
#
# 1. Der Datentyp ```int``` ist für die Darstellung von ganzen Zahlen gedacht.
# 2. Der Wert ```"23"``` ist vom Datentyp ```str```.
# 3. Die Anweisung ```"foo" + "bar"``` ist ungültig.
# 4. Der Datentyp ```bool``` hat zwei mögliche Werte.
#
# Löschen Sie die Nummern der nicht zutreffenden Behauptungen in der folgenden Zelle.

# %%
[1,2,3,4]

# %% [markdown]
# ### Aufgabe 2 (2 Punkte)
#
# Welche der folgenden Ausdrücke ergeben immer ```True```?
#
# 1. ```True or (a and False)```
# 2. ```not ((a or b) and False)```
# 3. ```b or not b```
# 4. ```not (a or True)```
#
# Löschen Sie die Nummern der Ausdrücke, die ```False``` ergeben könnten.

# %%
[1,2,3,4]

# %% [markdown]
# ### Aufgabe 3 (2 Punkte)
#
# Welche der folgenden Aussagen sind wahr?
#  1. Es gibt Programme, für die wir zwingend `for`-Schleifen brauchen, weil man sie mit `while`-Schleifen nicht schreiben könnte.
#  2. Es ist möglich, in einer `while`-Schleife eine `for`-Schleife zu schreiben.
#  3. Es ist nicht möglich, mit einer `for`-Schleife eine Endlosschleife zu bekommen.
#  4. Mit `for i in range(2)` iterieren wir durch die Zahlen `0` und `1`.
#
# Löschen Sie die Nummern der nicht zutreffenden Behauptungen in der folgenden Zelle.

# %%
[1,2,3,4]

# %% [markdown]
# ### Aufgabe 4 (2 Punkte)
#
# Welche der folgenden Aussagen sind wahr?
#
#  1. Die Grösse einer Liste ist veränderbar.
#  2. Die Grösse eines Tupels ist veränderbar.
#  3. In einem Dictionary können verschiedene Schlüssel den gleichen Wert haben.
#  4. Die Werte in einem Liste können Listen sein.
#
# Löschen Sie die Nummern der nicht zutreffenden Behauptungen in der folgenden Zelle.

# %%
[1,2,3,4]

# %% [markdown]
# ### Aufgabe 5 (2 Punkte)
#
# Welche der folgenden Aussagen sind wahr?
#
#  1. Eine Klasse kann sowohl Attribute als auch Methoden enthalten.
#  2. Eine Klasse kann Variablen vom Typ von sich selbst als Attribute enthalten.
#  3. Die Methode `__init__` braucht zwingend den Parameter `self`.
#  4. Alle Methoden einer Klasse sind Instanzmethoden.
#
# Löschen Sie die Nummern der nicht zutreffenden Behauptungen in der folgenden Zelle.

# %%
[1,2,3,4]

# %% [markdown]
# ## Code lesen, verstehen und verändern (6 Punkte)

# %% [markdown]
# ### Aufgabe 6 (2 Punkte)
#
# Gegeben ist die Funktion `mystery`. Beantworten Sie folgende Fragen:
# * Geben Sie für jedes der Argumente dieser Funktion einen Datentyp an, für den der Code funktioniert?
# * Was macht die Funktion (in einem Satz zusammengefasst).

# %%
def mystery(a, b):
    c = []
    for x in a.values():
        if x - b == 0:
            c.append(x)
    return c

# %% [markdown]
# * Ihre Antwort zur ersten Frage
# * Ihre Antwort zur zweiten Frage

# %% [markdown]
# ### Aufgabe 7 (2 Punkte)
#
# Der folgende Code soll die Anzahl gerader Zahlen zwischen zwei Zahlen berechnen. Leider hat sich bei der Implementation ein Fehler eingeschlichen. Ihre Aufgabe ist es, diesen Fehler zu finden.
#
# * Geben Sie ein Beispiel für einen Funktionsaufruf (also Werte für die Parameter), bei dem der Fehler nicht auftritt.
# * Beschreiben Sie, was das Problem ist.

# %%
def number_even(a, b):
    result = 0
    while a < b:
        if a % 2 == 0:
            result = result + 1
    return result

# %% [markdown]
# * Ihr Beispiel für einen Aufruf der nicht zum Fehler führt
# * Beschreibung des Problems

# %% [markdown]
# ### Aufgabe 8: Code anpassen (2 Punkte)
#
# Der folgende Code gibt alle Wörter in einer Liste `words` aus, die länger sind als 5 Zeichen.
# Ändern Sie den Code so, dass eine Liste dieser langen Wörter zurückgegeben wird, anstatt sie nur zu drucken.
#
# ```python
# def long_words(words):
#     for w in words:
#         if len(w) > 5:
#             print(w)
# ```

# %%
def long_words(words):
    for w in words:
        if len(w) > 5:
            print(w)

# %% [markdown]
# ## Programmieraufgaben (24 Punkte)

# %% [markdown]
# ### Aufgabe 9 (3 Punkte)
#
# Schreiben Sie eine Funktion `sum_multiples`, die zwei Zahlen `hi` und `a` erhält und die Summe aller Zahlen im Intervall `[1, hi]` (inklusive Grenzen) zurückgibt, die Vielfache von `a` sind. Als Beispiel soll `sum_multiples(12, 4)` das Resultat `24` zurückgeben, da $4+8+12=24$.

# %%
# Ihre Lösung

# %% [markdown]
# ### Aufgabe 10 (3 Punkte)
#
# Schreiben Sie eine Funktion `mirror`, welche eine Liste von Tupeln mit 2 Einträgen entgegennimmt.
# Die Funktion soll jedes Tupel in umgekehrter Reihenfolge in eine neue Liste schreiben und diese Liste zurückgeben.
# Als Beispiel soll aus der Liste `[(1,2), (3,4)]` die Liste `[(2,1), (4,3)]` erzeugt werden.

# %%
# Ihre Lösung

# %% [markdown]
# ### Aufgabe 11 (3 Punkte)
#
# Schreiben Sie eine Funktion `what_to_wear`, die drei Argumente entgegennimmt:
# die boolschen Parameter `is_raining` und `is_cold`, sowie einen String `item`, der die Werte `"raincoat"` oder `"jacket"` haben kann.
# Die Funktion soll `True` zurückgeben, wenn das Kleidungsstück getragen werden soll.
# Ein Regenmantel wird getragen, wenn es regnet (egal ob kalt oder warm).
# Eine Jacke wird getragen, wenn es kalt ist, aber nicht regnet.

# %%
# Ihre Lösung

# %% [markdown]
# ### Aufgabe 12 (3 Punkte)
#
# Schreiben Sie eine Funktion `avg_sum`, welche eine Liste von Zahlen als Argument entgegennimmt und ein Tupel zurückgibt, das den Durchschnitt und die Summe aller Elemente enthält.
# Falls die Liste leer ist, soll `None` zurückgegeben werden.

# %%
# Ihre Lösung

# %% [markdown]
# ### Aufgabe 13 (3 Punkte)
#
# Schreiben Sie eine *rekursive* Funktion `count_digits`, welche eine ganze Zahl `n` erhält und die Anzahl der Dezimalziffern bestimmt.
# Als Beispiel soll `count_digits(3051)` das Ergebnis `4` zurückgeben.

# %%
# Ihre Lösung

# %% [markdown]
# ### Aufgabe 14 (3 Punkte)
#
# Schreiben Sie eine Funktion `longest_unique_segment`, die eine Liste von Zahlen erhält und die Länge des längsten zusammenhängenden Bereichs ohne wiederholte Werte zurückgibt.
# Beispiel: In `[1,2,3,1,2]` ist eine längste solche Sequenz `[1,2,3]` mit Länge $3$.

# %%
# Ihre Lösung

# %% [markdown]
# ### Aufgabe 15 (6 Punkte)
#
# Sie müssen eine Anwendung zur Verwaltung eines Zoos schreiben. Dabei soll für jedes Tier der Name, die Spezies und das Alter gespeichert werden.
#
# * Schreiben Sie eine Klasse `Animal`. Die Klasse repräsentiert ein Tier und enthält die Attribute `name`, `species` und `age`.
# * Schreiben Sie dann eine Klasse `Zoo`. Diese soll eine Liste von Tieren verwalten und die Methoden `add_animal(animal)` zum Hinzufügen eines Tieres und `count_species(species)` zum Zurückgeben, wie viele Tiere einer bestimmten Spezies im Zoo sind implementieren.
# * Testen Sie ihr Programm indem Sie mindestens drei Tiere erstellen und dem Zoo hinzufügen und dann mindestens einmal die Methode `count_species` aufrufen.

# %%
# Ihre Lösung
