# %% [markdown]
# # Einführung in die Programmierung
# ## Prüfung vom 14. Januar 2026
# ### Zeit: 80 Minuten

# %% [markdown]
# *Schreiben Sie in dieses Feld Ihren Vornamen, Namen und email Adresse.*

# %% [markdown]
# ## Übersetzungstool
#
# Sie dürfen das Übersetzungstool [Google Translate](https://translate.google.com) verwenden.

# %% [markdown]
# ## Theorie (10 Punkte)

# %% [markdown]
# ### Aufgabe 1 (2 Punkte)
#
# Welche der folgenden Aussagen sind wahr?
#
# 1. Der Wert `3.7` ist vom Datentyp `int`.
# 2. Der Datentyp `str` ist zum Speichern von Text gedacht.
# 3. Ein Wert vom Typ `float` kann zu einem Wert vom Typ `int` addiert werden.
# 4. Das Ergebnis von `"1" + "2"` ist `"12"`.
#
# Löschen Sie die Nummern der nicht zutreffenden Behauptungen in folgender Zelle.

# %%
[1,2,3,4]

# %% [markdown]
# ### Aufgabe 2 (2 Punkte)
#
# Welche der folgenden Ausdrücke ergeben immer ```False```?
#
# 1. ```a and (b or True) and False```
# 2. ```not ((a or b) and False)```
# 3. ```b or not b```
# 4. ```not (a or True)```
#
# Löschen Sie die Nummern der Ausdrücke, die ```True``` ergeben könnten.

# %%
[1,2,3,4]

# %% [markdown]
# ### Aufgabe 3 (2 Punkte)
#
# Welche der folgenden Aussagen sind wahr?
#  1. Mit einer `for`-Schleife kann durch beliebige Listen iteriert werden.
#  2. Mit einer `while`-Schleife kann keine Endlosschleife erzeugt werden.
#  3. Mit `for i in range(3)` iteriert man durch die Zahlen 1, 2 und 3.
#  4. Es ist möglich, eine `while`-Schleife zu schreben, die nie ausgeführt wird.
#
# Löschen Sie die Nummern der nicht zutreffenden Behauptungen in der folgenden Zelle.

# %%
[1,2,3,4]

# %% [markdown]
# ### Aufgabe 4 (2 Punkte)
#
# Welche der folgenden Aussagen zu folgendem Code sind wahr?
#
# ```python
# a = ["first", 1, "second", 2]
# b = ("first", 1, "second", 2)
# c = {"first": 1, "second": 2}
# ```
#
#  1. Die Anweisung `a.append("third")` ist zulässig.
#  2. `b`ist eine Liste.
#  3. `c.values` hat zwei Elemente.
#  4. Der Ausdruck `c[1]` ergibt `"first"`.
#
# Löschen Sie die Nummern der nicht zutreffenden Behauptungen in der folgenden Zelle.

# %%
[1,2,3,4]

# %% [markdown]
# ### Aufgabe 5 (2 Punkte)
#
# Welche der folgenden Aussagen sind wahr?
#  1. Eine Klasse kann keine Listen als Attribute enthalten.
#  2. Beim Erstellen eines Objekts einer Klasse, wird die Funktion `__eq__` aufgerufen.
#  3. Eine Klasse wird mit dem Schlüsselwort `def` definiert.
#  4. Instanzmethoden einer Klasse müssen immer das Schlüsselwort `self` als ersten Parameter haben.
#
# Löschen Sie die Nummern der nicht zutreffenden Behauptungen in der folgenden Zelle.

# %%
[1,2,3,4]

# %% [markdown]
# ## Code lesen, verstehen und verändern (6 Punkte)

# %% [markdown]
# ### Aufgabe 6 (2 Punkte)
#
# Gegeben ist die Funktion `mystery`. Beantworten Sie folgende Fragen:
# * Geben Sie für jedes der Argumente dieser Funktion einen Datentyp an, für den der Code funktioniert?
# * Was macht die Funktion (in einem Satz zusammengefasst).

# %%
def mystery(a, b):
    c = a
    for x in b:
        if x > 0:
            c = c + 'x'
    return c

# %% [markdown]
# * Ihre Antwort zur ersten Frage
# * Ihre Antwort zur zweiten Frage

# %% [markdown]
# ### Aufgabe 7 (2 Punkte)
#
# Der folgende Code soll die Anzahl gerader Zahlen in einer Liste von Zahlen zurückgeben. Leider hat sich bei der Implementation ein Fehler eingeschlichen. Ihre Aufgabe ist es, diesen Fehler zu finden.
#
# * Geben Sie ein Beispiel für einen Funktionsaufruf (also Werte für die Parameter), bei dem der Fehler nicht auftritt.
# * Beschreiben Sie, was das Problem ist.

# %%
def number_even(lst):
    result = 0
    for n in lst:
        if n % 2 == 0:
            res = result + 1
    return result

# %% [markdown]
# * Ihr Beispiel für einen Aufruf der nicht zum Fehler führt
# * Beschreibung des Problems

# %% [markdown]
# ### Aufgabe 8: Code anpassen (2 Punkte)
#
# Der folgende Code verdoppelt jeden Wert in einer Liste `nums` und gibt das Ergebnis jeweils mit `print` aus.
# Passen Sie den Code so an, dass eine neue Liste mit den verdoppelten Werten zurückgegeben wird.
#
# ```python
# def double_values(nums):
#     for n in nums:
#         print(n * 2)
# ```

# %%
def double_values(nums):
    for n in nums:
        print(n * 2)

# %% [markdown]
# ## Programmieraufgaben (24 Punkte)

# %% [markdown]
# ### Aufgabe 9 (3 Punkte)
#
# Schreiben Sie eine Funktion ```sum_ending_with```, welche als Argumente eine Zahl ```hi``` und eine Ziffer ```d``` entgegennimmt, und dann die Summe aller Zahlen im Interval ```[1, hi]``` (inklusive Grenzen), deren letzte Ziffer `d` ist, zurückgibt. Als Beispiel soll der Aufruf ```sum_ending_with(30, 7)``` das Resultat ```51``` zurückgeben, da $7+17+27=51$.

# %%
# Ihre Lösung

# %% [markdown]
# ### Aufgabe 10 (3 Punkte)
#
# Schreiben Sie eine Funktion `pair_sum`, die eine Liste von Tupeln mit 2 Zahlen erhält.
# Die Funktion soll eine Liste erzeugen und zurückgeben, die jeweils die Summe der Werte enthält.
# Als Beispiel soll aus der Liste ```[(3, 4), (1, 7), (0, 0)]``` die Liste ```[7, 8, 0]``` erzeugt werden.

# %%
# Ihre Lösung

# %% [markdown]
# ### Aufgabe 11 (3 Punkte)
#
# Schreiben Sie eine Funktion `use_transport`, welche drei Argumente entgegennimmt: Die boolschen Parameter
# `is_raining` und `is_far`, sowie eine Variable `vehicle` (vom Typ String) welcher die Werte `"bike"` und `"walk"` annehmen kann.
# Die Funktion soll `True` zurückgeben, wenn das übergebene Verkehrsmittel benutzt werden soll.
# Zu Fuss gehen geht nur, wenn es nicht regnet und es nicht weit ist.
# Fahrradfahren geht nur, wenn es nicht regnet (Entfernung spielt keine Rolle).

# %%
# Ihre Lösung

# %% [markdown]
# ### Aufgabe 12 (3 Punkte)
#
# Schreiben Sie eine Funktion `shortest_longest_word`, die eine Liste von Strings entgegennimmt und ein Tupel zurückgibt, das das kürzeste und das längste Wort der Liste enthält. Sie dürfen annehmen, dass alle Strings unterschiedliche Länge haben.
# Falls die Liste leer ist, soll `None` zurückgegeben werden.

# %%
# Ihre Lösung

# %% [markdown]
# ### Aufgabe 13 (3 Punkte)
#
# Schreiben Sie eine *rekursive* Funktion `rec_reverse`, die einen String `s` erhält und diesen String in umgekehrter Reihenfolge zurückgibt.
# Als Beispiel soll der Aufruf `rec_reverse("hallo")` den String `"ollah"` zurückgeben.

# %%
# Ihre Lösung

# %% [markdown]
# ### Aufgabe 14 (3 Punkte)
#
# Schreiben Sie eine Funktion `max_segment_sum`, welche eine Liste von Zahlen entgegennimmt und die grösste Summe eines zusammenhängenden Teilsegments zurückgibt.
# Beispiel: Für `[−2, 1, 3, −1, 2]` wäre das Ergebnis $5$, da `1 + 3 + −1 + 2 = 5` die maximale Segment-Summe ist.

# %%
# Ihre Lösung

# %% [markdown]
# ### Aufgabe 15 (6 Punkte)
#
# Sie müssen eine Anwendung zur Verwaltung einer Bibliothek schreiben. Dabei soll für jedes Buch der Name, der Autor und das Jahr gespeichert werden.
#
# * Schreiben Sie eine Klasse `Book`. Die Klasse repräsentiert ein Buch und enthält die Attribute `title`, `author` und `year`.
# * Schreiben Sie dann eine Klasse `Library`. Diese soll eine Liste von Büchern verwalten und die Methoden `add_book(book)` zum Hinzufügen eines Buches und `count_by_author(author)` zum Zurückgeben, wie viele Bücher eines bestimmten Autors in der Bibliothek sind implementieren.
# * Testen Sie ihr Programm indem Sie mindestens drei Bücher erstellen und der Bibliothek hinzufügen und dann mindestens einmal die Methode `count_by_author` aufrufen.

# %%
# Ihre Lösung
